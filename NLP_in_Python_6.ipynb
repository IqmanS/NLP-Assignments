# %% [markdown]
# <a href="https://colab.research.google.com/github/IqmanS/NLP-Assignments/blob/main/NLP_in_Python_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# !wget https://github.com/IqmanS/NLP-Assignments/raw/main/data/dtm.pkl -q
# !wget https://github.com/IqmanS/NLP-Assignments/raw/main/data/cv.pkl -q
# !wget https://github.com/IqmanS/NLP-Assignments/raw/main/data/data_clean.pkl -q
# !wget https://github.com/IqmanS/NLP-Assignments/raw/main/data/corpus.pkl -q

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                  transcript         full_name
# ali       \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...          Ali Wong
# amy       \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Amy Schumer
# anthony   \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAntho...  Anthony Jeselnik
# beth      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...     Beth Stelling
# bill      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBILL ...         Bill Burr
# burr      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...         Bill Burr
# dave      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...    Dave Chappelle
# dylan     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDylan...       Dylan Moran
# hasan     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHasan...      Hasan Minhaj
# jim       \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJIM J...     Jim Jefferies
# joe       \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...         Joe Rogan
# john      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...      John Mulaney
# kathleen  \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...  Kathleen Madigan
# kevin     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...        Kevin Hart
# lewis     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Lewis Black
# louis     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...        Louis C.K.
# matt      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...         Matt Rife
# mike      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...    Mike Birbiglia
# pete      \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...     Pete Davidson
# ricky     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...     Ricky Gervais
# sammy     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Sammy Obeid
# trevor    \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Trevor Noah
# wanda     \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...       Wanda Sykes

# %%
import re

trans = []
for i in data.index:
    trans.append(re.sub("\n","",data.loc[i]["transcript"]))
data["transcript"] = trans

# %%
data
# Out:
#                                                  transcript         full_name
# ali        Ali Wong: Baby Cobra (2016) | Transcript - Sc...          Ali Wong
# amy        Amy Schumer: Emergency Contact (2023) | Trans...       Amy Schumer
# anthony    Anthony Jeselnik: Thoughts And Prayers (2015)...  Anthony Jeselnik
# beth       Beth Stelling: Girl Daddy (2020) | Transcript...     Beth Stelling
# bill       BILL BURR: I'M SORRY YOU FEEL THAT WAY (2014)...         Bill Burr
# burr       Bill Burr: Paper Tiger (2019) - Transcript - ...         Bill Burr
# dave       Dave Chappelle: The Age of Spin (2017) - Tran...    Dave Chappelle
# dylan      Dylan Moran: Off The Hook (2015) - Transcript...       Dylan Moran
# hasan      Hasan Minhaj at 2017 White House Corresponden...      Hasan Minhaj
# jim        JIM JEFFERIES: BARE (2014) - Full Transcript ...     Jim Jefferies
# joe        Joe Rogan: Triggered (2016) - Transcript - Sc...         Joe Rogan
# john       John Mulaney: The Comeback Kid (2015) - Trans...      John Mulaney
# kathleen   Kathleen Madigan: Hunting Bigfoot (2023) | Tr...  Kathleen Madigan
# kevin      Kevin Hart: Seriously Funny (2010) – Transcri...        Kevin Hart
# lewis      Lewis Black: Tragically, I Need You (2023) | ...       Lewis Black
# louis      Louis C.K.: Oh My God (2013) | Transcript - S...        Louis C.K.
# matt       Matt Rife: Natural Selection (2023) | Transcr...         Matt Rife
# mike       Mike Birbiglia: My Girlfriend's Boyfriend (20...    Mike Birbiglia
# pete       Pete Davidson: Turbo Fonzarelli (2024) | Tran...     Pete Davidson
# ricky      Ricky Gervais: Humanity (2018) | Transcript -...     Ricky Gervais
# sammy      Sammy Obeid: Martyr in a Safe Space (2022) | ...       Sammy Obeid
# trevor     Trevor Noah: Where Was I (2023) | Transcript ...       Trevor Noah
# wanda      Wanda Sykes: I'm an Entertainer (2023) | Tran...       Wanda Sykes

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# ' Ali Wong: Baby Cobra (2016) | Transcript - Scraps from the loft   \r\t\tSkip to content MOVIESMOVIE REVIEWSMOVIE TRANSCRIPTSSTANLEY KUBRICKTV SERIESTV SHOW TRANSCRIPTSCOMEDYSTAND-UP COMEDY TRANSCRIPTSGE'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'': ['Ali',
#   '',
#   '\r\t\tSkip',
#   'MenuMOVIESMOVIE',
#   'MenuMOVIESMOVIE',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Leave',
#   'Instagram',
#   'Access',
#   'yes,'],
#  'Ali': ['Wong:', 'Wong:', 'Wong!Hi.', 'Wong.'],
#  'Wong:': ['Baby', 'Baby'],
#  'Baby': ['Cobra', 'Cobra'],
#  'Cobra': ['(2016)', '(2016)'],
#  '(2016)': ['|', '|'],
#  '|': ['Transcript',
#   'Transcript',
#   'Transcript\t\t\tKelsey',
#   'Transcript\t\t\tDylan',
#   'Transcript\t\t\tDusty',
#   'Transcript\t\t\tJack'],
#  'Transcript': ['-', '\t\t\t\t\t\t\t\t\t\tSeptember'],
#  '-': ['Scraps'],
#  'Scraps': ['from', 'from'],
#  'from': ['the',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Pier',
#   'Harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'holding',
#   'bacteria',
#   'Harvard',
#   'his',
#   'the'],
#  'the': ['loft',
#   'rocky',
#   'stage:',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'center',
#   'hoarding',
#   'HPV',
#   'country',
#   'third',
#   'Communists.The',
#   'worst',
#   'calculator',
#   'future.',
#   'Tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside,',
#   'inside.',
#   'first',
#   'time,',
#   'fifth',
#   'back',
#   'park.”',
#   'middle',
#   'money',
#   'colonizer!”',
#   'time.',
#   'sexiest.',
#   'sexiest.',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference.',
#   'Chinese,',
#   'Japanese.',
#   'East',
#   'west',
#   'name,',
#   'bathroom.',
#   'bathroom',
#   'corner.',
#   'wait',
#   'wall…',
#   'fuck',
#   'house.Him',
#   'idea',
#   'man’s',
#   'message,',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'C.O.O.',
#   'table',
#   'top.',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret.”',
#   'phrase,',
#   'street.',
#   'Boat',
#   'best',
#   'desert.',
#   'stall.',
#   'end',
#   'day',
#   'Goonies.',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet.',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'Internet',
#   'back.',
#   'Internet',
#   'Jewish',
#   'universe',
#   'pain.”',
#   'pain.',
#   'pain.',
#   'dick.',
#   'butt,',
#   'tush-tush.',
#   'man',
#   'look',
#   'man’s',
#   'first',
#   'woman,',
#   'Lord',
#   'Rim,',
#   'most',
#   'most',
#   'woman',
#   'time,',
#   'boss.',
#   'boss',
#   'time,',
#   'bedroom,',
#   'boss.',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'baby’s',
#   'dream.”',
#   'point.',
#   'ultimate',
#   'world',
#   'rest',
#   'Galapagos,',
#   'phrase',
#   'women,',
#   'side',
#   'hood,',
#   'movie,',
#   'park,',
#   'sun.',
#   'sun',
#   'Tupac',
#   'time?',
#   'time,',
#   'peace',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood.',
#   'eggs',
#   'month,',
#   "Kraken!'”",
#   'time,',
#   'smiley',
#   'ovulation',
#   'time,',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'size',
#   'twins',
#   'toilet,',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table?”',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house.',
#   'dishes?”',
#   'plants?”',
#   'channel.”I',
#   'star',
#   'show.',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same.',
#   'escrow',
#   'one',
#   'epicenter',
#   'privacy',
#   'Loft.',
#   'best'],
#  'loft': [''],
#  '\r\t\tSkip': ['to'],
#  'to': ['content',
#   'pregnancy,',
#   'the',
#   'get',
#   'pee',
#   'sleep,',
#   'sleep.',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'Deepak-Oprah,',
#   'achieve',
#   'trap',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women.',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work.',
#   'earn',
#   'shit',
#   'seat.',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'make',
#   'just',
#   'the',
#   'podcasts.',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'you.I',
#   'put',
#   'do',
#   'help',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do.',
#   'her,',
#   'use',
#   'say,',
#   'get',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me.',
#   'me',
#   'live',
#   'die.',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go.',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be.',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish,',
#   'finish.',
#   'come',
#   'make',
#   'be',
#   'be…',
#   'be',
#   'me,',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'Keyser',
#   'freak',
#   'freak',
#   'it.”',
#   'cleanse.',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me.',
#   'Harvard',
#   'reflect',
#   'read',
#   'your'],
#  'content': ['MOVIESMOVIE'],
#  'MOVIESMOVIE': ['REVIEWSMOVIE', 'REVIEWSMOVIE'],
#  'REVIEWSMOVIE': ['TRANSCRIPTSSTANLEY',
#   'TRANSCRIPTSSTANLEY',
#   'TRANSCRIPTSSTANLEY',
#   'TRANSCRIPTSSTANLEY'],
#  'TRANSCRIPTSSTANLEY': ['KUBRICKTV', 'KUBRICKTV', 'KUBRICKTV', 'KUBRICKTV'],
#  'KUBRICKTV': ['SERIESTV', 'SERIESTV', 'SERIESTV', 'SERIESTV'],
#  'SERIESTV': ['SHOW', 'SHOW', 'SHOW', 'SHOW'],
#  'SHOW': ['TRANSCRIPTSCOMEDYSTAND-UP',
#   'TRANSCRIPTSCOMEDYSTAND-UP',
#   'TRANSCRIPTSCOMEDYSTAND-UP',
#   'TRANSCRIPTSCOMEDYSTAND-UP'],
#  'TRANSCRIPTSCOMEDYSTAND-UP': ['COMEDY', 'COMEDY', 'COMEDY', 'COMEDY'],
#  'COMEDY': ['TRANSCRIPTSGEORGE',
#   'TRANSCRIPTSGEORGE',
#   'TRANSCRIPTSGEORGE',
#   'TRANSCRIPTSGEORGE'],
#  'TRANSCRIPTSGEORGE': ['CARLINDAVE', 'CARLINDAVE', 'CARLINDAVE', 'CARLINDAVE'],
#  'CARLINDAVE': ['CHAPPELLEINTERVIEWSPLAYBOY',
#   'CHAPPELLEINTERVIEWSPLAYBOY',
#   'CHAPPELLEINTERVIEWSPLAYBOY',
#   'CHAPPELLEINTERVIEWSPLAYBOY'],
#  'CHAPPELLEINTERVIEWSPLAYBOY': ['INTERVIEWSMUSICHISTORYBOOKS',
#   'INTERVIEWSMUSICHISTORYBOOKS',
#   'INTERVIEWSMUSICHISTORYBOOKS',
#   'INTERVIEWSMUSICHISTORYBOOKS'],
#  'INTERVIEWSMUSICHISTORYBOOKS': ['', 'Search', '', 'Search'],
#  'MenuMOVIESMOVIE': ['REVIEWSMOVIE', 'REVIEWSMOVIE'],
#  'Search': ['Search', 'MOVIESMOVIE', 'SearchCOMEDY'],
#  'SearchCOMEDY': ['Ali'],
#  '\t\t\t\t\t\t\t\t\t\tSeptember': ['19,'],
#  '19,': ['2017\t\t\t\t\t\t\t\tAli'],
#  '2017\t\t\t\t\t\t\t\tAli': ["Wong's"],
#  "Wong's": ['stand'],
#  'stand': ['up'],
#  'up': ['special',
#   'jealous.',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards.',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'don’t',
#   'about',
#   'to',
#   'a',
#   'to',
#   'with',
#   'there',
#   'on',
#   'the',
#   'myself',
#   'from',
#   'your',
#   'soldier'],
#  'special': ['delves', 'MOVIES'],
#  'delves': ['into'],
#  'into': ['her',
#   'cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure.',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'her': ['sexual',
#   'get',
#   'to',
#   'book',
#   'Lululemon',
#   'butt.”',
#   'nipples,',
#   'pussy',
#   'white',
#   'I'],
#  'sexual': ['adventures,'],
#  'adventures,': ['hoarding,'],
#  'hoarding,': ['the'],
#  'rocky': ['road'],
#  'road': ['to'],
#  'pregnancy,': ['and'],
#  'and': ['why',
#   'gentlemen,',
#   'foremost,',
#   'then',
#   'have',
#   'there’s',
#   'resentment',
#   'get',
#   'get',
#   'says,',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'she',
#   'I',
#   'I',
#   'I',
#   'we',
#   'watched',
#   'I',
#   'have',
#   'that',
#   'recycling,',
#   'disturbing',
#   'it’s',
#   'all',
#   'just…',
#   'be',
#   'half-Vietnamese.',
#   'his',
#   'slide.',
#   'your',
#   'inflamed',
#   'you’re',
#   'I',
#   'half-Japanese',
#   'I’m',
#   'half-Vietnamese.',
#   'playing',
#   'rugby.',
#   'foremost,',
#   'a',
#   'emotionally',
#   'I',
#   '20',
#   'neither',
#   'I',
#   'I–',
#   'then',
#   'it’s',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'very',
#   'for',
#   'I',
#   'she',
#   'rise',
#   'be',
#   'eat',
#   'watch',
#   'be',
#   'now',
#   'most',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say,',
#   'my',
#   'he',
#   'when',
#   'I’m',
#   'sicker,',
#   'sicker.',
#   'sicker,',
#   'sicker,',
#   'posted',
#   'that’s',
#   'lies.',
#   'as',
#   'treat',
#   'you’ll',
#   'succeed,',
#   'they',
#   'that’s',
#   'be',
#   'just',
#   'sisters.',
#   'a',
#   'unusual',
#   'they’ll',
#   'boring.”',
#   'wearing',
#   'famous',
#   'you’re',
#   'just',
#   'therefore,',
#   'ignore',
#   'the',
#   'Biggie',
#   'your',
#   'there',
#   'I',
#   'Push',
#   'then,',
#   'melt',
#   'I',
#   'then',
#   'sniff',
#   'I',
#   'you’ve',
#   'outside',
#   'as',
#   'rapey',
#   'most',
#   'see',
#   'I’d',
#   'I',
#   'he',
#   'instead',
#   'remember',
#   'hold',
#   'I',
#   'do',
#   'to',
#   'a',
#   'terrible.',
#   'I',
#   'when',
#   'I',
#   'held',
#   'got',
#   'I',
#   'your',
#   'he',
#   'I',
#   'leaves',
#   'dark.',
#   'naked,',
#   'a',
#   'my',
#   'then',
#   'recently',
#   'a',
#   'self-discovery,',
#   'relationships,',
#   'whimsy',
#   'truths\t\t\t\tDusty',
#   'Southern',
#   'cultural'],
#  'why': ['feminism', 'people', 'you', 'are', 'we’re', 'I’m'],
#  'feminism': ['is', 'is'],
#  'is': ['terrible\t\t',
#   '“Fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'that?”',
#   'a',
#   'a',
#   'Asian.',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like,',
#   'always,',
#   'called',
#   'the',
#   'a',
#   'to',
#   'that…',
#   'doo',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   '80,',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious!”',
#   'so',
#   'it'],
#  'terrible\t\t': ['Ladies'],
#  'Ladies': ['and'],
#  'gentlemen,': ['please'],
#  'please': ['welcome'],
#  'welcome': ['to'],
#  'stage:': ['Ali'],
#  'Wong!Hi.': ['Hello!'],
#  'Hello!': ['Welcome!', 'Hello.'],
#  'Welcome!': ['Thank'],
#  'Thank': ['you!', 'you', 'you,', 'you.More:Ali'],
#  'you!': ['Thank'],
#  'you': ['for',
#   'don’t',
#   'go',
#   'can',
#   'never',
#   'better',
#   'under',
#   'might',
#   'die.”',
#   'wanna',
#   'gotta',
#   'a',
#   'drop',
#   'know,',
#   'know,',
#   'feel',
#   'know.',
#   'know,',
#   'about',
#   'to',
#   'know,',
#   'right',
#   'get',
#   'like!',
#   'know?My',
#   'know?',
#   'know,',
#   'can',
#   'eat',
#   'queef',
#   'know,',
#   'know',
#   'marry',
#   'something.',
#   'would',
#   'don’t',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry,',
#   'never',
#   'dare',
#   'know,',
#   'deep,',
#   'not',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know…',
#   'now.',
#   'gotta',
#   'don’t',
#   'put',
#   'know?',
#   'haven’t',
#   'know,',
#   'stick',
#   'know?',
#   'just',
#   'as',
#   'know?My',
#   'OK?',
#   'all',
#   'respect',
#   'need',
#   'know?',
#   'what',
#   'be',
#   'so,',
#   'know?',
#   'know',
#   'guys',
#   'gonna',
#   'know?Another',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know?I',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'scratch',
#   'can',
#   'urgently',
#   'gotta',
#   'need',
#   'do',
#   'when',
#   'when',
#   'to',
#   'know?',
#   'that–',
#   'know',
#   'push,',
#   'push,',
#   'push,',
#   'think',
#   'wash',
#   'water',
#   'makin’',
#   'about',
#   'get',
#   'know?',
#   'know,',
#   'see',
#   'know?',
#   'know,',
#   'think'],
#  'for': ['coming.',
#   'coming.Um…',
#   'me.',
#   'me.',
#   'me',
#   'my',
#   'fashion',
#   'warmth?',
#   'marriage,',
#   'them.',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us,',
#   'Fresh',
#   'me',
#   'them.',
#   'his',
#   'the',
#   'once.',
#   'the',
#   'all',
#   'the',
#   'me',
#   'me,',
#   'me',
#   'a',
#   'granted',
#   'a',
#   'a',
#   'me.',
#   'a',
#   '30',
#   'coming',
#   'the',
#   'playing',
#   'being'],
#  'coming.': ['Hello!', 'You'],
#  'Hello.': ['We'],
#  'We': ['are',
#   'were',
#   'were',
#   'had',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'do',
#   'eat',
#   'got',
#   'had',
#   'could',
#   'don’t',
#   'could',
#   'all',
#   'don’t'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'C.E.O.s,',
#   'never',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin’.',
#   'in',
#   'marked'],
#  'gonna': ['have',
#   'turn',
#   'die…',
#   'overtake',
#   'have',
#   'trap',
#   'propose…',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live.',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear,',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be.',
#   'recycle…',
#   'burn',
#   'be.',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'HPV',
#   'it',
#   'HPV',
#   'HPV,',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to,',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex,',
#   'to',
#   'had',
#   'to',
#   'the'],
#  'get': ['this',
#   'it.',
#   'it.',
#   'rid',
#   'it,',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker,',
#   'sicker,',
#   'really,',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant.',
#   'pregnant,',
#   'up',
#   'into',
#   'older.',
#   'as',
#   'a',
#   'pregnant.',
#   'pregnant',
#   'that…',
#   'my',
#   'pregnant,',
#   'huge',
#   'dark',
#   'big–',
#   'big,',
#   'all',
#   'pregnant.'],
#  'this': ['shit',
#   'year.',
#   'doctor,',
#   'shit',
#   'shit',
#   'calculator',
#   'Judy',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'restaurant',
#   'restaurant',
#   'hippy-dippy',
#   'sneaking',
#   'wacky',
#   'dude,',
#   'dude,',
#   'huge',
#   'shit?',
#   'conversation.',
#   'is',
#   'fucking',
#   'relatable',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit.”',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream',
#   'field'],
#  'shit': ['over',
#   'and',
#   'around?',
#   'around?',
#   'up',
#   'is',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'was',
#   'together',
#   'together.”My',
#   'turns',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore.',
#   'that'],
#  'over': ['with,', 'again.', 'again.', 'by', 'his'],
#  'with,': ['’cause'],
#  '’cause': ['I',
#   'it',
#   'it',
#   'my',
#   'you’re',
#   'when',
#   'her',
#   'it’s',
#   'you',
#   'I'],
#  'I': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'don’t',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am,',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew,',
#   'was',
#   'dropped',
#   'was',
#   'don’t',
#   'get',
#   'mean,',
#   'just',
#   'could',
#   'think',
#   'was',
#   'don’t',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee,',
#   'need',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted.',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'was.People',
#   'did',
#   'don’t',
#   'don’t.',
#   'straight',
#   'don’t',
#   'do',
#   'don’t',
#   'don’t',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said,',
#   'really',
#   'don’t',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'don’t',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was,',
#   'got',
#   'just',
#   'don’t–',
#   'don’t!',
#   'don’t!',
#   'like',
#   'respect',
#   'know',
#   'don’t',
#   'also',
#   'just',
#   'can’t',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want?',
#   'wanna',
#   'don’t',
#   'am',
#   'dare',
#   'just',
#   'identify.”',
#   'don’t',
#   'was',
#   'won,',
#   'was',
#   'really',
#   'changed',
#   'get',
#   'need',
#   'don’t',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'know,',
#   'slime',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'don’t',
#   'had',
#   'can’t',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'don’t',
#   'was',
#   'lost.',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'can’t',
#   'can',
#   'am',
#   'didn’t',
#   'can’t',
#   'get',
#   'do',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didn’t',
#   'didn’t',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'don’t',
#   'accept'],
#  'pee': ['in,', 'on'],
#  'in,': ['like,', 'OK?'],
#  'like,': ['ten',
#   '“You',
#   '“But…',
#   '“Oh,',
#   '“Oh,',
#   '“All',
#   'we',
#   '“Hey,',
#   '“Wassup?”',
#   '“Hey,',
#   '“Where?”',
#   '“At',
#   '“Oh,',
#   'you',
#   '“I',
#   '“Hold',
#   '“I',
#   '“It’s',
#   '“It’s',
#   'private',
#   '“Oh,',
#   '“I’m',
#   '“Shut',
#   '“Oh,',
#   'very',
#   '“We’re',
#   '“We',
#   '“But,',
#   '“Look',
#   '“That',
#   '“Oh,',
#   '“You',
#   '“Hey,',
#   '“Why',
#   '“Uh,',
#   '“Oh,',
#   '“Oh,',
#   '“Yes,',
#   'become',
#   'a',
#   '“Guys,',
#   '“That’s',
#   '“Ali,',
#   '“Yeah,',
#   '“Why',
#   '“Yeah,',
#   '“Yeah!',
#   '“Oh,',
#   '“I’m',
#   '“Oh,',
#   'only',
#   '“We’re',
#   '‘Release',
#   'we',
#   '“OK,',
#   '“Hey,',
#   '“Oh,',
#   '“Uh,',
#   '“No!”',
#   '“Yes!”',
#   '“You',
#   '“Yeah,',
#   'that',
#   'this',
#   'I',
#   'a',
#   'a',
#   'really',
#   '“Why',
#   'way'],
#  'ten': ['minutes.', 'gallons'],
#  'minutes.': ['But'],
#  'But': ['thank',
#   'my',
#   'I',
#   'he',
#   'sometimes,',
#   'don’t',
#   'I',
#   'he’s',
#   'mostly',
#   'I’m',
#   'it’s'],
#  'thank': ['you,'],
#  'you,': ['everybody,', 'five', 'but', 'right?”', 'I', '’cause', 'boom,'],
#  'everybody,': ['so'],
#  'so': ['much',
#   'emotional.',
#   'emotional',
#   'much',
#   'vulnerable',
#   'smooth,',
#   'that',
#   'good.',
#   'many',
#   'that',
#   'that',
#   'in',
#   'that',
#   'do',
#   'annoying',
#   'that',
#   'lonely.',
#   'juicy.',
#   'hot.',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'little',
#   'little',
#   'supportive.”',
#   'that',
#   'that'],
#  'much': ['for', 'better', 'chemistry.', 'shittier', 'Netflix', 'resentment,'],
#  'coming.Um…': ['It’s'],
#  'It’s': ['a',
#   'been',
#   'OK.',
#   'coming.',
#   'really',
#   'what',
#   'like',
#   'so',
#   'all',
#   'different.',
#   'a',
#   'a',
#   'basically',
#   'like',
#   'because',
#   'very',
#   'so',
#   'a',
#   'lonely.',
#   'very',
#   'when',
#   'super',
#   'whatevs,',
#   'not'],
#  'a': ['very',
#   'very',
#   'shit',
#   'six-pack,',
#   'Ambien',
#   'Meditation',
#   'fucking',
#   'ghost',
#   'self-help',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictator’s',
#   'shovel',
#   'climax',
#   'Texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'grown-ass',
#   'mattress',
#   'kitchen.',
#   'very',
#   'catch.',
#   'secret',
#   'public',
#   'hipster?',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'Yoko',
#   'white',
#   'white',
#   'Wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin.',
#   'slip',
#   'Jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend.',
#   'shitty',
#   'new',
#   'man',
#   'Pinterest',
#   'Saturday.',
#   'completely',
#   'lot',
#   'genius.”',
#   'housewife,',
#   'great',
#   'lot.',
#   'great',
#   'office',
#   'office',
#   'office.',
#   'day,',
#   'sad-ass',
#   'MacGyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'disgusting',
#   'pervert.',
#   'gross',
#   'very',
#   'young',
#   'idiot,',
#   'result,',
#   'little',
#   'second',
#   'conqueror.',
#   'little–',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife,',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk,',
#   'quarter,',
#   'princess.I',
#   'Vietnam',
#   'half',
#   'female',
#   'baby,',
#   'week',
#   'little',
#   'sudden.',
#   'frozen',
#   'lot',
#   'lot',
#   'kid.',
#   'kid?',
#   'lot',
#   'kid,',
#   'kid?',
#   'Asian',
#   'billion.',
#   'turtle',
#   'right',
#   'U-turn!”',
#   'O-turn!”',
#   'car',
#   'mess.',
#   'full',
#   'century',
#   'living.',
#   'fuck.',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smoker’s',
#   'side',
#   'sandwich.',
#   'way',
#   'doctor.',
#   'kid,',
#   'lot',
#   'lot',
#   'while,',
#   'bunch',
#   'dictatorship,',
#   'hand',
#   'man',
#   'zombie,',
#   'half',
#   'miscarriage,',
#   'lot',
#   'miscarriage.',
#   'third',
#   'pair',
#   'reason.',
#   'heartbeat.”',
#   'miscarriage.',
#   'month',
#   'bike',
#   'doula.',
#   'doula',
#   'white',
#   'soft',
#   'baby',
#   'child',
#   'marriage,',
#   'eyeball,',
#   'foot?',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye.',
#   'Minion.',
#   'year,',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good',
#   'Comment',
#   'week'],
#  'very': ['exciting',
#   'exciting',
#   'unusual',
#   'confusing…',
#   'picturesque',
#   'underrated.',
#   'well',
#   'surprised',
#   'soft,',
#   'nurturing',
#   'domestic.',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing,',
#   'clinical.',
#   'universal',
#   'grateful',
#   'common.',
#   'early.',
#   'much.',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'and',
#   'was',
#   'jobs,',
#   'long.',
#   'looks',
#   'since.',
#   'long.',
#   'on'],
#  'me.': ['It’s',
#   'I',
#   'And',
#   '‘Cause',
#   'When–',
#   'OK?”',
#   'You',
#   'Because',
#   'Like,',
#   'That’s',
#   'And',
#   '“Oh,',
#   'I',
#   'Oh,',
#   'How'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'Ali'],
#  'year': ['for', 'I'],
#  'turned': ['33'],
#  '33': ['this', 'and…'],
#  'year.': ['Yes!', 'Uh,'],
#  'Yes!': ['Thank'],
#  'five': ['people.', 'years,', 'years,'],
#  'people.': ['I', 'It’s…', 'Like,', 'I', 'That’s'],
#  'appreciate': ['that.'],
#  'that.': ['Uh,', 'Uh,', 'They', 'Don’t', 'I’m', 'They’re', 'I'],
#  'Uh,': ['I', 'this', 'we'],
#  'can': ['tell',
#   'also',
#   'I',
#   'I',
#   'never',
#   'you',
#   'be',
#   'tell,',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk,',
#   'comfortably',
#   'tell,',
#   'just',
#   'think',
#   'I',
#   'I',
#   'I',
#   'already',
#   'really',
#   'you',
#   'already',
#   'see,',
#   'find'],
#  'tell': ['that',
#   'that',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'you',
#   'because',
#   'you'],
#  'that': ['I’m',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'I',
#   'I’m',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'I’m',
#   'he',
#   'your',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement…',
#   'for',
#   'you',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'he',
#   'you’re',
#   'I',
#   'I',
#   'so',
#   'he’d',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'we’ll',
#   'fucking',
#   'housewife,',
#   'horrible',
#   'one-ply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'I',
#   'if',
#   'he’s',
#   'and',
#   'you',
#   'if',
#   'then,',
#   'they’re',
#   'fear.',
#   'fear',
#   'he',
#   'we',
#   'I’m',
#   'I',
#   'woman',
#   'now,',
#   'Whole',
#   'was',
#   'was',
#   'everybody',
#   'it’s',
#   'came',
#   'she’s',
#   '’cause',
#   'to',
#   'you',
#   'snail-trail',
#   'my',
#   'were',
#   'it',
#   'it’s',
#   'tell',
#   'means,',
#   'they',
#   'they',
#   'day',
#   'says,',
#   'stupid-ass',
#   'I',
#   'Harvard',
#   'I',
#   'shit',
#   'is?',
#   'you’re',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'he’s',
#   'goes',
#   'they',
#   'the',
#   'the',
#   'I’m',
#   'my'],
#  'I’m': ['getting',
#   'straight',
#   'jealous,',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'half-Chinese',
#   'half-Chinese',
#   'a',
#   'very',
#   'like,',
#   "done.'”",
#   'done.',
#   'not',
#   'a–',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed,',
#   'still',
#   'just',
#   'older,',
#   'not',
#   'only',
#   'only',
#   'gonna',
#   '33,',
#   '33.',
#   'from,',
#   'very,',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked.',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older,', 'older,', 'busy', 'massages'],
#  'older,': ['because,', 'because', 'when'],
#  'because,': ['now,', 'usually,', 'last'],
#  'now,': ['when', 'because', 'instead', 'and', 'if'],
#  'when': ['I',
#   'they',
#   'a',
#   'you’re',
#   'she',
#   'we',
#   'you',
#   'you',
#   'I',
#   'you’re',
#   'a',
#   'our',
#   'you',
#   'we',
#   'I',
#   'I',
#   'I',
#   'I',
#   'you',
#   'he',
#   'I',
#   'that',
#   'you',
#   'you’re',
#   'they',
#   'I',
#   'I’m',
#   'I',
#   'I',
#   'my',
#   'you',
#   'trying',
#   'I',
#   'everything',
#   'I',
#   'the',
#   'it’s',
#   'it',
#   'they',
#   'I',
#   'he',
#   'a',
#   'they',
#   'they',
#   'you’re',
#   'they',
#   'I',
#   'they’re',
#   'you’re',
#   'you',
#   'he',
#   'you',
#   'I',
#   'it',
#   'it’s'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'who’s',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'Beyoncé.',
#   'how',
#   'how',
#   'if',
#   'me'],
#  'an': ['18-year-old', 'ATM', 'impression', 'investment'],
#  '18-year-old': ['girl,', 'girls,'],
#  'girl,': ['my', 'because'],
#  'my': ['automatic',
#   'body',
#   'Kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life.',
#   'generation.',
#   'time.',
#   'mom',
#   'optimum',
#   'husband,',
#   'league,',
#   'God,',
#   'God,',
#   'part.',
#   'generation.',
#   'Volvo.',
#   'pussy.',
#   'God.',
#   'God.',
#   'bed',
#   'husband',
#   'God!',
#   'Pinterest',
#   'best',
#   'wedding',
#   'husband,',
#   'personality',
#   'heart.',
#   'financial',
#   'friends,',
#   'co-workers.',
#   'toilet',
#   'fingers',
#   'co-workers',
#   'co-workers',
#   'shit',
#   'husband',
#   'life?',
#   'destiny.',
#   'last',
#   'mom,',
#   'dad,',
#   'grandma.”',
#   '20s,',
#   'God!',
#   'God!',
#   'husband',
#   'Asian-American',
#   'female',
#   'friends',
#   'husband',
#   'mind,',
#   'mind',
#   'God,',
#   'face',
#   'husband',
#   'destiny,',
#   'body',
#   'God,',
#   'fault.',
#   '20s,',
#   'uterus',
#   'progesterone',
#   'writing',
#   'co-workers,',
#   'underwear,',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers?',
#   'fingers?',
#   'fingers?”',
#   'husband',
#   'God,',
#   'husband',
#   'face',
#   'God.',
#   'mom–',
#   'six-week',
#   'God,',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband.',
#   'husband',
#   'doctor’s',
#   'God.',
#   'blood',
#   'husband',
#   'pussy’s',
#   'pussy’s',
#   'body’s',
#   'husband,',
#   'league,',
#   'God,',
#   'dreams',
#   'beautiful,',
#   'hard-earned',
#   'ass.'],
#  'automatic': ['thought…'],
#  'thought…': ['is'],
#  '“Fuck': ['you.”', 'you.'],
#  'you.”': ['“Fuck', 'My'],
#  'you.': ['I', 'A', 'Don’t', 'There’s–', 'Ghostbusters!”I', 'You'],
#  'don’t': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta…',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'wanna',
#   'wanna',
#   'worry,',
#   'cheat',
#   'wanna',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack.”',
#   'die.',
#   'die.',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'tell',
#   'work,'],
#  'even': ['know', 'know…', 'accidentally', 'effective.', 'have', 'come'],
#  'know': ['you,',
#   'what',
#   'that',
#   'when',
#   'what',
#   'when',
#   'what’s',
#   'why',
#   'the',
#   'anything',
#   'what',
#   'that',
#   'how',
#   'how',
#   'you',
#   'that',
#   'I',
#   'you',
#   'you’ve',
#   'what',
#   'if',
#   'what’s',
#   'the',
#   'why',
#   'what’s',
#   'what',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'that.',
#   'that'],
#  'but': ['fuck', 'I', 'it’s', 'I', 'I’m', 'my'],
#  'fuck': ['you!”', 'they', 'up!', 'down.', 'one', 'him', 'up.”', 'I'],
#  'you!”': ['‘Cause'],
#  '‘Cause': ['I’m', 'he', 'I', 'it’s', 'if', 'she', 'I'],
#  'straight': ['up', 'up', 'up'],
#  'jealous.': ['I’m'],
#  'jealous,': ['first'],
#  'first': ['and',
#   'met',
#   'thing',
#   'dates,',
#   'and',
#   'lady',
#   'WebMD.When',
#   'home'],
#  'foremost,': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them.',
#   'men',
#   'two',
#   'HPV.',
#   'Wolverine,',
#   'Grey,',
#   'Tidying',
#   'success.',
#   'all',
#   'my',
#   'shit.',
#   'my',
#   'a',
#   'you',
#   'my',
#   'success.”I',
#   'losers.',
#   'losers.',
#   'skaters.',
#   'my',
#   'my',
#   'people',
#   'opinions,',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'Los',
#   'all,',
#   'bleach,',
#   'your',
#   'this',
#   'Asian',
#   'us',
#   'the',
#   'my',
#   'Facebook,',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence.',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   '“No!',
#   'the',
#   'control,',
#   'control',
#   'being',
#   'her,',
#   'saying,',
#   'saying:',
#   'income',
#   'one.',
#   'them.',
#   'shit.',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere.',
#   'their',
#   'her',
#   'those',
#   'longevity.I',
#   'change.',
#   'mother',
#   'science',
#   'that…',
#   'my',
#   'the',
#   'people',
#   'fuckin’?”',
#   'the',
#   'that,',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him…',
#   'this',
#   'that',
#   'me.',
#   'women',
#   'women',
#   'shoes.',
#   'poppy',
#   'me',
#   'Craigslist.',
#   'childbirth.',
#   'women',
#   'the',
#   'your',
#   'life,',
#   'how',
#   'my',
#   'the',
#   'survival,',
#   'another',
#   'those',
#   'body',
#   'losers.',
#   'my',
#   'white-collar',
#   'Use',
#   'Stand-Up'],
#  'their': ['metabolism.',
#   'feet',
#   'whole',
#   'house.',
#   'communist',
#   'shit,',
#   'doo',
#   'hallways',
#   'iPad',
#   'eyebrows,',
#   'prostate.',
#   'fame',
#   'existence.',
#   'big-ass',
#   'Darth',
#   'arch-nemesis,',
#   'eyes',
#   'eyes.',
#   'eyes',
#   'head',
#   'eyelids.',
#   'face…',
#   '20s',
#   'husbands'],
#  'metabolism.': ['Because'],
#  'Because': ['18-year-old', 'according', 'I’m', 'I’m', 'we’re'],
#  'girls,': ['they'],
#  'they': ['could',
#   'take',
#   'put',
#   'go',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'mean.',
#   'don’t',
#   'purposely',
#   'don’t',
#   'want.',
#   'want.You',
#   'say',
#   'wax',
#   'do',
#   'like',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'don’t',
#   'can',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldn’t',
#   'go',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph.',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'crush',
#   'kill',
#   'like',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'put',
#   'felt',
#   'wanted',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'waiting',
#   'keep',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding.',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'scratch',
#   'vacuum,',
#   'come',
#   'give',
#   'got',
#   'twerk,',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like',
#   'gluten-free,',
#   'all',
#   'that',
#   'it,',
#   'snacks',
#   'a',
#   'bananas.”'],
#  'like': ['shit,',
#   'to',
#   'Fifty',
#   'the',
#   '$200.',
#   'this',
#   'the',
#   'to',
#   'you’re',
#   'voting',
#   'that',
#   'I’m',
#   'making',
#   'a',
#   'loofah',
#   'responsibility.',
#   'host',
#   'Filipino',
#   'to',
#   'to',
#   'that.',
#   'free-range',
#   'we',
#   'you’re',
#   'wiping',
#   'it’s',
#   'you’re',
#   'I',
#   'I’m',
#   'a',
#   'it,',
#   'that',
#   'he’s',
#   'you’re',
#   'to',
#   'a',
#   'the',
#   'skittles.',
#   'a',
#   'everything',
#   'a',
#   'they',
#   'losing',
#   'fingers.',
#   'Whoppers',
#   'a',
#   'when'],
#  'shit,': ['and', 'too.'],
#  'then': ['they',
#   'after',
#   'also,',
#   'Asian',
#   'if',
#   'afterwards,',
#   'it',
#   'I',
#   'you',
#   'you',
#   'your',
#   'if',
#   'I',
#   'I',
#   'resist',
#   'he',
#   'I',
#   'she',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'six-pack,': ['right?'],
#  'right?': ['They', 'That’s', 'So,', 'You'],
#  'They': ['got',
#   'don’t',
#   'don’t',
#   'have',
#   'don’t',
#   'just',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'ruined',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'try',
#   'don’t',
#   'don’t',
#   'don’t',
#   'can',
#   'can',
#   'would',
#   'get',
#   'just',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'just',
#   'make',
#   'watch',
#   'were',
#   'tried'],
#  'got': ['that-that',
#   'so',
#   'married.',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married.',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'married,',
#   'pregnant,'],
#  'that-that': ['beautiful'],
#  'beautiful': ['inner'],
#  'inner': ['thigh', 'peace', 'evil,'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'I', 'the', 'the', 'I'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'now', 'to', 'when'],
#  'there’s': ['that', 'multiple'],
#  'huge': ['gap', 'unspoken', 'sit-down', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is'],
#  'with': ['the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him.',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes.',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me,',
#   'it,',
#   'you',
#   'intention,',
#   'me.',
#   'your',
#   'my',
#   'personal',
#   'light-hearted'],
#  'light': ['of', 'completely.”'],
#  'potential': ['just'],
#  'radiating': ['through.And'],
#  'through.And': ['then,'],
#  'then,': ['when',
#   'all',
#   'it',
#   'you',
#   'on',
#   'at',
#   'at',
#   'a',
#   'when',
#   'because',
#   'I',
#   'you',
#   'I'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home…',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'bald…',
#   'to',
#   'time,”',
#   'through',
#   'to'],
#  'sleep,': ['they'],
#  'sleep.': ['Right?'],
#  'Right?': ['They'],
#  'insomnia': ['yet.'],
#  'yet.': ['They', 'They'],
#  'what': ['it’s',
#   'that',
#   'your',
#   'that',
#   'love',
#   'the',
#   'I',
#   'happens',
#   'he',
#   'to',
#   'I’m',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'I',
#   'that',
#   'a'],
#  'it’s': ['like',
#   'undetectable',
#   'a',
#   'very,',
#   'hot',
#   'funny,',
#   'too',
#   'probably',
#   'been',
#   'very',
#   'because',
#   'OK,',
#   'like',
#   'the',
#   'sexist',
#   'a',
#   'what',
#   'a',
#   'all',
#   'too',
#   'Easter',
#   'like,',
#   'go',
#   'not',
#   'because',
#   'different.',
#   'straight',
#   'Neosporin.So,'],
#  'Ambien': ['or'],
#  'or': ['download',
#   'you’re',
#   'you',
#   'for',
#   'something.',
#   'whatever.',
#   'something…'],
#  'download': ['a'],
#  'Meditation': ['Oasis'],
#  'Oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind.',
#   '30s',
#   'wealth.',
#   'butt',
#   'mom.',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'co-worker’s',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame,',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers.',
#   'first',
#   '20s,',
#   '30s,',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg,',
#   'life.',
#   'doctor’s',
#   'body',
#   'e-mail',
#   'inbox!',
#   'e-mail'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind.': ['They'],
#  'whole': ['lives', 'manipulation', 'new', 'thing.”'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them.': ['They', 'They’re', 'Nothing', 'Once', 'They'],
#  'HPV': ['yet.', 'yet,', 'is', 'will'],
#  'sleep': ['in'],
#  'in': ['peace',
#   'men.',
#   'women’s',
#   'the',
#   'books',
#   'The',
#   'handy',
#   'San',
#   'eight',
#   'a',
#   'San',
#   'broad',
#   'the',
#   'a',
#   'America',
#   'a',
#   'my',
#   'it.',
#   'the',
#   'and',
#   'men.',
#   '2012.',
#   'my',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time!”♪',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed.',
#   'control',
#   'the',
#   'elementary',
#   'the',
#   'their–',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'your',
#   'such',
#   'the',
#   'Atlanta.',
#   'their',
#   'front',
#   'my',
#   'labor,',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'debt.',
#   'British'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night.',
#   'home',
#   'this',
#   'the',
#   'Golden',
#   'any',
#   'how,',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life,',
#   'first.',
#   'home,',
#   'any',
#   'my',
#   'Fresh',
#   'some',
#   'my',
#   'work.',
#   'him.',
#   'his',
#   'Knoxville’s'],
#  'night.': ['Everybody', 'And'],
#  'Everybody': ['has', 'has', 'has'],
#  'has': ['HPV,',
#   'it.',
#   'it.',
#   'HPV.',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'HPV,': ['OK?', 'because'],
#  'OK?': ['Everybody',
#   'I’m',
#   'That',
#   'So,',
#   'A',
#   'I',
#   'You',
#   'So,',
#   'Are',
#   'We',
#   'I',
#   'Old',
#   'Do',
#   'When',
#   'When',
#   'They',
#   'Are'],
#  'it.': ['It’s',
#   'If',
#   'You',
#   'It’s',
#   'You',
#   'Second',
#   'So,',
#   'I',
#   'When',
#   'That’s'],
#  'OK.': ['Come', 'And'],
#  'Come': ['out'],
#  'out': ['already.',
#   'of',
#   'there',
#   'of',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first.',
#   'that',
#   'of',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'about',
#   'yet',
#   'of',
#   'of'],
#  'already.': ['Everybody'],
#  'If': ['you', 'it', 'a', 'you’re', 'you', 'it’s'],
#  'it': ['yet,',
#   'might',
#   'all',
#   'when',
#   'was',
#   'on',
#   'can',
#   'on',
#   'don’t',
#   'was',
#   'on',
#   'on',
#   'as',
#   'so',
#   'for',
#   'a',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up.',
#   'up,',
#   'interesting.',
#   'in',
#   'before,',
#   'tonight.',
#   'might',
#   'up.',
#   'was',
#   'in',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'made',
#   'gets',
#   'was',
#   'so',
#   'as',
#   'very',
#   'takes',
#   'also',
#   'easier.',
#   'was',
#   'different?”',
#   'up,',
#   'all',
#   'turns'],
#  'yet,': ['you', 'you’re'],
#  'You': ['go',
#   'don’t',
#   'wanna',
#   'homeless',
#   'go',
#   'feel',
#   'feel',
#   'know?But',
#   'get',
#   'don’t',
#   'guys',
#   'mess',
#   'guys',
#   'can',
#   'gotta',
#   'guys',
#   'tell',
#   'ain’t',
#   'have',
#   'gotta',
#   'gotta',
#   'only',
#   'know',
#   'know?',
#   'know',
#   'know,',
#   'just',
#   'could',
#   'guys',
#   'pee',
#   'know',
#   'know',
#   'just',
#   'change',
#   'owe'],
#  'you’re': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like,',
#   'too',
#   'like,',
#   'about',
#   'paranoid',
#   'like,',
#   'a',
#   'really',
#   'married,',
#   'gonna',
#   'fucking',
#   'the',
#   'supposed',
#   'eating',
#   'gonna',
#   'in',
#   '33,',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser,', 'housewife.', 'different', 'baby.', 'baby,'],
#  'loser,': ['all'],
#  'all': ['right?',
#   'about.',
#   'of',
#   'your',
#   'came',
#   'required',
#   'this',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day,',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'he’s',
#   'squirmy',
#   'right?',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off.'],
#  'That’s': ['what',
#   'what',
#   'where',
#   'right,',
#   'how',
#   'how',
#   'right.',
#   'the',
#   'when',
#   'not',
#   'the',
#   'not',
#   'shit',
#   'right.',
#   'so',
#   'my',
#   'why',
#   'a',
#   'the',
#   'not'],
#  'says': ['about', 'to'],
#  'about': ['you.',
#   'the',
#   'him',
#   'a',
#   'Vietnamese',
#   'it',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money.',
#   'anal.',
#   'is,',
#   'that',
#   'is,',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'A': ['lot', 'lot', 'woman', 'lot', 'lot', 'whole', 'lot'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['don’t', 'are', 'are', 'as'],
#  'because': ['it’s',
#   'my',
#   'my',
#   'you',
#   'what?',
#   'before',
#   'I',
#   'being',
#   'he’s',
#   'he’s',
#   'you',
#   'I',
#   'you',
#   'I',
#   'the',
#   'he',
#   'you',
#   'we’re',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'uh,',
#   'they’re',
#   'they’re',
#   'then',
#   'the',
#   'we’re',
#   'when',
#   'the',
#   'I',
#   'if',
#   'my–',
#   'he'],
#  'undetectable': ['in'],
#  'men.': ['It’s', 'We'],
#  'really': ['fucked',
#   'work,',
#   'meant',
#   'scared',
#   'am!”',
#   'take',
#   'am',
#   'hot,'],
#  'fucked': ['up.', 'a', 'up'],
#  'up.': ['HPV', 'A', 'You', 'She’s'],
#  'ghost': ['that'],
#  'inside': ['men’s', 'of'],
#  'men’s': ['bodies'],
#  'bodies': ['and'],
#  'says,': ['“Boo!”', '“Please,'],
#  '“Boo!”': ['in'],
#  'women’s': ['bodies.', 'intuition.'],
#  'bodies.': ['My'],
#  'My': ['doctor', 'husband,', 'Toyota', 'mom', 'nipples'],
#  'doctor': ['told', 'says', 'appointments.'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'me': ['that',
#   'that',
#   'to',
#   'something.',
#   'off?”',
#   'feel',
#   'to',
#   'feel',
#   'the',
#   'tell',
#   'about',
#   'with',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on,',
#   'and',
#   'enough',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'see',
#   'of',
#   'company',
#   'when',
#   'when',
#   'anymore.',
#   'extremely',
#   'in',
#   'while',
#   'to',
#   'a',
#   'out.',
#   'out',
#   'to',
#   'money,',
#   'in',
#   'for'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'of', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'Latina', 'sacks,', 'weeks'],
#  'strains': ['of'],
#  'HPV.': ['Either', 'Very'],
#  'Either': ['I'],
#  'kind': ['that’s', 'where', 'of', 'of', 'of', 'of'],
#  'that’s': ['gonna',
#   'right,',
#   'not',
#   'like…',
#   'not',
#   'gonna',
#   'why',
#   'the',
#   'cool…',
#   'so',
#   'like',
#   'enough'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'cervical': ['cancer…'],
#  'cancer…': ['…or'],
#  '…or': ['I'],
#  'body': ['will', 'is', 'hair', 'is', 'odor.', 'was', 'when', 'where,'],
#  'will': ['heal',
#   'also',
#   'also',
#   'you',
#   'always',
#   'be',
#   'have',
#   'commend',
#   'not'],
#  'heal': ['itself.', 'from'],
#  'itself.': ['Very'],
#  'Very': ['helpful,', 'lucky'],
#  'helpful,': ['this'],
#  'doctor,': ['right?'],
#  'So,': ['basically,',
#   'you',
#   'we’re',
#   'he',
#   'you',
#   'you’re',
#   'I',
#   'when',
#   'now,',
#   'I',
#   'my',
#   'then',
#   'then',
#   'I',
#   'as'],
#  'basically,': ['either'],
#  'either': ['I’m'],
#  'die…': ['or'],
#  'presence': ['of'],
#  'Wolverine,': ['bitches.'],
#  'bitches.': ['We’ll', 'I'],
#  'We’ll': ['find'],
#  'find': ['out.Um,', 'a', 'ways', 'a', 'it'],
#  'out.Um,': ['I'],
#  'also': ['tell', 'disappear.', 'got', 'last', 'don’t', 'decided', 'takes'],
#  'Kindle': ['is'],
#  'turning': ['into', 'into'],
#  'self-help': ['library.'],
#  'library.': ['I’m'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic,',
#   'recognize',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again!”',
#   'Rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'OK.',
#   'fuckin’.',
#   'because',
#   'doing',
#   'there.',
#   'gonna',
#   'like',
#   'the',
#   'be'],
#  'interested': ['in', 'in'],
#  'books': ['like'],
#  'Fifty': ['Shades'],
#  'Shades': ['of'],
#  'Grey,': ['OK?'],
#  'The': ['Life-Changing',
#   'manual.',
#   'next',
#   'advantage',
#   'fancy',
#   'images',
#   'Boat,',
#   'Hustler'],
#  'Life-Changing': ['Magic'],
#  'Magic': ['of'],
#  'Tidying': ['Up.'],
#  'Up.': ['Yes.'],
#  'Yes.': ['Yes,', 'Yes.', 'Yes.', 'I', 'Because'],
#  'Yes,': ['that’s'],
#  'right,': ['how', 'Ali,', 'we', 'because', 'I’ve'],
#  'how': ['to',
#   'can',
#   'proposals',
#   'rotten',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'there’s,',
#   'it'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'all', 'and', 'together.'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success.': ['That’s'],
#  '30s': ['is'],
#  'about.': ['How'],
#  'How': ['can', 'did', 'did', 'did'],
#  'around?': ['I’m', 'Help'],
#  'horrible': ['person,', 'toilet'],
#  'person,': ['I’m'],
#  'happy': ['with'],
#  'am,': ['how'],
#  'Help': ['me,'],
#  'me,': ['Tony',
#   'he’s',
#   'this',
#   'but',
#   'I',
#   'because',
#   '“Oh,',
#   'I’m',
#   'out',
#   'with'],
#  'Tony': ['Robbins,'],
#  'Robbins,': ['help'],
#  'help': ['me!I', 'her', 'you', 'as'],
#  'me!I': ['have'],
#  'hoarding': ['problem,', 'goes', 'problem'],
#  'problem,': ['which'],
#  'which': ['I’m',
#   'is',
#   'means',
#   'would',
#   'their',
#   'is',
#   'is',
#   'means',
#   'subsequently'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems.', 'homeless', 'day.', 'shitty'],
#  'problems.': ['I’m'],
#  'if': ['the',
#   'he',
#   'you',
#   'you',
#   'I',
#   'you',
#   'you',
#   'I',
#   'you',
#   'I’m',
#   'I',
#   'he',
#   'you',
#   'I',
#   'I'],
#  'goes': ['away,', 'down'],
#  'away,': ['the'],
#  'disappear.': ['I', 'That’s'],
#  'problem': ['because'],
#  'mom': ['is', 'got', 'is', 'is'],
#  'third': ['world', 'grade,', 'world'],
#  'world': ['country', '♪It', 'with', 'country,'],
#  'country': ['and', 'and'],
#  'she': ['taught', 'refused', 'was', 'wrote', 'knows', 'is', 'was', 'said,'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called'],
#  'throw': ['away', 'up.', 'up'],
#  'away': ['anything,', 'from', 'at'],
#  'anything,': ['because'],
#  'dictator’s': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth.': ['So,'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade,': ['’cause'],
#  'might': ['come', 'need', 'mean'],
#  'come': ['in', 'out,', 'up', 'out,', 'out', 'home,', 'with', 'out'],
#  'handy': ['as'],
#  'as': ['a',
#   'a',
#   'an',
#   'women',
#   'much',
#   'they',
#   'a',
#   'many',
#   'possible',
#   'the',
#   'freaky',
#   'me.',
#   'a',
#   'old',
#   'her.',
#   'wet',
#   'it',
#   'pent-up,',
#   'angry',
#   'possible.',
#   'leverage',
#   'it'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'in', 'makin’'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['and', 'hole.', 'with', 'hole', 'cheeks', 'hole.'],
#  'running': ['away'],
#  'Communists.The': ['last'],
#  'last': ['time',
#   'forever.',
#   'boyfriend',
#   'time',
#   'year,',
#   'boyfriend',
#   'year,'],
#  'time': ['I', 'shitting', 'I', 'I', 'you'],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like,',
#   'like,',
#   'like,',
#   'that,',
#   'attending',
#   'like,',
#   'a',
#   'like,',
#   'living',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'Cuban',
#   'like,',
#   'like,',
#   'like,',
#   'legit,',
#   'gonna',
#   'ready.',
#   'ripe.',
#   'rotten.',
#   'free?',
#   'like,',
#   'you.',
#   'like,',
#   'like,',
#   'like,',
#   'very',
#   'magical.A',
#   'to',
#   'sliced',
#   'sliced',
#   'like,',
#   'like,',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   'in',
#   'OK,',
#   'clearly',
#   'that',
#   'Easter',
#   'so',
#   'about',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   '18',
#   'like,',
#   'like,',
#   '$70,000'],
#  'San': ['Francisco,', 'Francisco,'],
#  'Francisco,': ['I', 'when'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'rid': ['of'],
#  'shit.': ['Don’t', 'My', 'You’re', 'It’s'],
#  'Don’t': ['ever', 'try', 'your', 'kill', 'feel'],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know…',
#   'fancy',
#   'yoga.',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'it.',
#   'it',
#   'anything.',
#   'it!',
#   'anything.”',
#   'write',
#   'that.',
#   'whatever',
#   'that.',
#   'all',
#   'anal',
#   'it.Sheryl',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'in',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   'a',
#   'it?',
#   'you'],
#  'mom.': ['It', 'People'],
#  'It': ['was',
#   'was',
#   'was',
#   'cost',
#   'could',
#   'was',
#   'happened',
#   'happened',
#   'basically',
#   'tells',
#   'was,',
#   'makes'],
#  'worst': ['experience', 'thing'],
#  'experience': ['of', 'some'],
#  'life.': ['It', 'And'],
#  'emotional.': ['We'],
#  'were': ['screaming',
#   'all',
#   'in',
#   'hipsters,',
#   'getting',
#   'done,',
#   'like,',
#   'discouraging',
#   'like,',
#   '18',
#   'alarmingly',
#   'suppositories,',
#   'trying',
#   'like,',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['to', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['to', 'to'],
#  'let': ['go', 'it', 'their'],
#  'Texas': ['Instruments'],
#  'Instruments': ['TI-82…'],
#  'TI-82…': ['manual.'],
#  'manual.': ['The', 'She'],
#  'She': ['don’t', 'doesn’t'],
#  'know…': ['where', 'that', 'freaked'],
#  'calculator': ['is.', 'is.', 'that'],
#  'is.': ['Those', 'It'],
#  'Those': ['of'],
#  'under': ['25'],
#  '25': ['probably'],
#  'probably': ['don’t', 'Pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation.': ['We', 'You'],
#  'required': ['to'],
#  'buy': ['it'],
#  'we': ['were',
#   'had,',
#   'had…',
#   'were',
#   'were',
#   'spend',
#   'pay',
#   'eat',
#   'eat',
#   'do…',
#   'are',
#   'have',
#   'as',
#   'better',
#   'have',
#   'had',
#   'walk',
#   'just',
# ...
#  'trap': ['his', 'his', 'his'],
#  'his': ['ass.”',
#   'ass!”',
#   'ass',
#   'other',
#   'family',
#   'lunch',
#   'earning',
#   'butt',
#   'eyes,',
#   'eyes',
#   'neck,',
#   'head',
#   'self-esteem',
#   'ass.',
#   'life,'],
#  'ass.”': ['“Going'],
#  '“Going': ['to'],
#  'ass!”': ['And'],
#  'trapped': ['his', 'your', 'me.'],
#  'ass': ['initially', 'into', 'into', 'into'],
#  'initially': ['by'],
#  'by': ['not',
#   'the',
#   'the',
#   'Sheryl',
#   'the',
#   'white',
#   'a',
#   'me,',
#   'a',
#   'saying,',
#   'lifting',
#   'keeping'],
#  'kissing': ['him'],
#  'until': ['the', 'he', 'he', 'my', 'I’m'],
#  'fifth': ['date,'],
#  'date,': ['which'],
#  'unusual': ['move', 'to'],
#  'move': ['on'],
#  'part.': ['But'],
#  'did': ['it', 'not', 'he', 'that', 'anal,', 'have', 'you', 'he', 'he'],
#  'purpose,': ['because'],
#  'knew': ['that'],
#  'catch.': ['So'],
#  'So': ['I', 'embarrassing.', 'that,', 'much', 'that'],
#  '“All': ['right,'],
#  'Ali,': ['you', 'we'],
#  'gotta': ['make',
#   'explain',
#   'threaten',
#   'work',
#   'shit',
#   'shit',
#   'use',
#   'do',
#   'use',
#   'muffle',
#   'worry',
#   'try',
#   'take',
#   'go',
#   'change',
#   'change',
#   'keep',
#   'check',
#   'stay.',
#   'keep'],
#  'make': ['this',
#   'difficult',
#   'a',
#   'sure',
#   'a',
#   'this',
#   'a',
#   'a',
#   'sure',
#   'him'],
#  'dude': ['believe', 'you', 'eats', 'and', 'named'],
#  'believe': ['that', 'that.”', 'he', 'that'],
#  'secret': ['garden.”'],
#  'garden.”': ['When,'],
#  'When,': ['really,'],
#  'really,': ['it’s', 'you', 'I'],
#  'public': ['park…'],
#  'park…': ['…that'],
#  '…that': ['has', 'blows'],
#  'hosted': ['many'],
#  'many': ['reggae', 'more', 'men'],
#  'reggae': ['fests…'],
#  'fests…': ['…and'],
#  '…and': ['has', 'half-jungle'],
#  'accidentally': ['let…'],
#  'let…': ['two'],
#  'homeless': ['people', 'or', 'friends,', 'dude!'],
#  'people': ['inside.',
#   'are',
#   'all',
#   'don’t',
#   'until',
#   'doing',
#   'were',
#   'will'],
#  'hipsters,': ['OK?'],
#  'store': ['Urban'],
#  'Urban': ['Outfitters'],
#  'Outfitters': ['has'],
#  'made': ['things', 'into', 'it,', 'me', 'you'],
#  'things': ['very', 'like'],
#  'confusing…': ['for'],
#  'hipster?': ['Is'],
#  'Is': ['that'],
#  'beard': ['for'],
#  'fashion': ['or'],
#  'warmth?': ['It'],
#  'happened': ['to…', 'in', 'to'],
#  'to…': ['It', 'Now,'],
#  'living': ['there,'],
#  'there,': ['and', 'through', 'OK?'],
#  'guy': ['in'],
#  'broad': ['daylight'],
#  'daylight': ['and'],
#  'had,': ['like,'],
#  'had…': ['We'],
#  'had': ['so',
#   'been',
#   'this',
#   'been',
#   'this',
#   'tried',
#   'it',
#   'to',
#   'a',
#   'to',
#   'the',
#   'this',
#   'a',
#   'such',
#   'this',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'a',
#   'one,',
#   'the',
#   'dated'],
#  'chemistry.': ['He'],
#  '“Hey,': ['wassup?”', 'can', 'I', 'hey!', 'can'],
#  'wassup?”': ['I'],
#  '“Wassup?”': ['And'],
#  'we–': ['The'],
#  'next': ['thing', 'century'],
#  'knew,': ['we'],
#  'back': ['of', 'out', 'in', 'of', 'in'],
#  'Volvo.': ['And'],
#  'after': ['we', 'they'],
#  'done,': ['he'],
#  'drop': ['me'],
#  'off?”': ['I'],
#  '“Where?”': ['He'],
#  '“At': ['the'],
#  'park.”': ['And'],
#  'dropped': ['him'],
#  'off': ['at', 'and', 'of'],
#  'Golden': ['Gate'],
#  'Gate': ['Park'],
#  'Park': ['and'],
#  'watched': ['him'],
#  'run': ['into', 'over'],
#  'middle': ['with'],
#  'friends,': ['and', 'when', 'dead.', 'dead.', 'dead.'],
#  'no!”': ['“I'],
#  '“I': ['just',
#   'could',
#   'did',
#   'saw',
#   'just',
#   'gotta',
#   'don’t',
#   'changed',
#   'slime',
#   'am'],
#  'dude!': ['Again!”My'],
#  'Again!”My': ['husband'],
#  'husband': ['is',
#   'and',
#   'recently.',
#   'is',
#   'to',
#   'and',
#   'dies.”',
#   'isn’t',
#   'and',
#   'a',
#   'down',
#   'will',
#   'for',
#   'on,',
#   'was'],
#  'Asian.': ['Which', 'Yeah!'],
#  'Which': ['a', 'is…', 'means', 'is', 'is', 'he’s', 'is'],
#  'shocked': ['by,'],
#  'by,': ['because,'],
#  'usually,': ['Asian-American'],
#  'Asian-American': ['women', 'men', 'brothers'],
#  'women': ['who,',
#   'all',
#   'should',
#   'had',
#   'get',
#   'get',
#   'who',
#   'who',
#   'who',
#   'would',
#   'won’t',
#   'tried'],
#  'who,': ['like,'],
#  'know,': ['wear',
#   'because',
#   'white',
#   'it’s',
#   'just',
#   'learning',
#   'I',
#   'squeeze',
#   'it’s–',
#   'and',
#   'a',
#   'is',
#   'I–',
#   'they',
#   'I–'],
#  'wear': ['these', 'that'],
#  'these': ['kinda',
#   'bitches.',
#   'Chinese',
#   'women',
#   'boring,',
#   'other',
#   'hormone',
#   'ovulation'],
#  'kinda': ['glasses'],
#  'glasses': ['and'],
#  'opinions,': ['they'],
#  'date': ['white'],
#  'white': ['dudes.',
#   'dude',
#   'dude,',
#   'dudes,',
#   'dude.',
#   'dude',
#   'man!',
#   'people',
#   'people.',
#   'friends,',
#   'hippie'],
#  'dudes.': ['You'],
#  'any': ['hipster', 'moment,', 'real', 'sort', 'black', 'given'],
#  'hipster': ['neighborhood'],
#  'neighborhood': ['in'],
#  'major': ['city'],
#  'city': ['in'],
#  'America': ['and'],
#  'Yoko': ['Ono'],
#  'Ono': ['factory.'],
#  'factory.': ['It’s…'],
#  'It’s…': ['too', 'amazing.', 'It’s'],
#  'too': ['much.', 'nice.', 'old', 'late', 'stupid', 'funky,'],
#  'much.': ['I', 'For'],
#  'what’s': ['wrong', 'gonna', 'wrong'],
#  'wrong': ['with', 'with'],
#  'it,': ['you', 'you', 'and', 'that', 'when', 'just…'],
#  'being': ['with', 'the', 'courageous.'],
#  'feel': ['very…',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad,'],
#  'very…': ['You'],
#  'picturesque': ['when'],
#  'dude,': ['you', 'focus', 'and'],
#  'know.': ['You'],
#  'Wes': ['Anderson'],
#  'Anderson': ['movie'],
#  'movie': ['or'],
#  'dudes,': ['they'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling,': ['and'],
#  'disturbing': ['documentaries.'],
#  'documentaries.': ['They'],
#  'introduce': ['you'],
#  'very,': ['you', 'very'],
#  'hot': ['hookin’'],
#  'hookin’': ['up'],
#  'dude.': ['I', 'Do', 'That’s–'],
#  'mean,': ['nothing'],
#  'nothing': ['makes', 'for'],
#  'makes': ['me', 'me', 'sense,'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome',
#   'transcriptsWeekly'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy.': ['Oh,'],
#  'Oh,': ['my', 'my', 'you', 'my', 'my', 'my'],
#  'God.': ['I', 'It’s', 'That’s', 'I'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement…': ['…you'],
#  '…you': ['know,'],
#  'right': ['there,', 'now!', 'moment', 'turn–', 'there.', 'after'],
#  'through': ['the', 'Southeast', 'and', 'a', 'it.', 'a'],
#  'money': ['hole', 'if'],
#  'hole': ['and', 'feels'],
#  'just…': ['And', 'Let’s', '“I', 'And'],
#  'also,': ['he’s'],
#  'vulnerable': ['down'],
#  'down': ['there.', 'there,', 'your', 'immediately', 'in', 'so', 'with'],
#  'there.': ['I’m,', 'I', 'But'],
#  'I’m,': ['like,', 'like,'],
#  'crush': ['your'],
#  'head': ['at', 'shredding', 'and', 'for'],
#  'moment,': ['white', 'you'],
#  'man!': ['I'],
#  'kill': ['you', 'me!'],
#  'now!': ['Crush'],
#  'Crush': ['those', 'while'],
#  'those': ['brains!', 'comments.', 'green', 'old', 'doctor', 'crazy'],
#  'brains!': ['Colonize'],
#  'Colonize': ['the'],
#  'colonizer!”': ['You'],
#  'know?But': ['I'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'it’s',
#   'of',
#   'about',
#   'that’s',
#   'so.',
#   'I’m'],
#  'marriage,': ['it', 'because'],
#  'nice': ['to'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race.', 'goddamn'],
#  'race.': ['The'],
#  'advantage': ['is'],
#  'home…': ['and'],
#  'racist': ['together.'],
#  'together.': ['You', 'And,'],
#  'say': ['whatever', 'to', 'be'],
#  'whatever': ['you', 'they', 'you', 'the'],
#  'like!': ['You'],
#  'explain': ['shit.'],
#  'half-Filipino,': ['half-Japanese.'],
#  'half-Japanese.': ['I’m'],
#  'half-Chinese': ['and', 'and'],
#  'half-Vietnamese.': ['And', 'So,'],
#  'spend': ['100'],
#  '100': ['percent'],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time',
#   'first',
#   'Buddha',
#   'careers.',
#   'day',
#   'society',
#   'first',
#   'weekly'],
#  'shitting': ['on'],
#  'Korean': ['people.'],
#  'amazing.': ['It’s'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on,'],
#  'on,': ['you', 'you', 'like,'],
#  'know?My': ['last', 'husband'],
#  'boyfriend': ['was', 'because'],
#  'Cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'I',
#   'crash.”',
#   'simultaneously',
#   'explode.',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'Mexican': ['people', 'friends,'],
#  '“Hold': ['it.'],
#  'guys': ['aren’t', 'know', 'about', 'need', 'had.”', 'can', 'doin’'],
#  'aren’t': ['Mexican?”'],
#  'Mexican?”': ['Asian-American'],
#  'underrated.': ['I'],
#  'sexiest.': ['Asian', 'They'],
#  'Asian': ['men', 'men,', 'people.', 'female', 'woman,', 'don’t', 'ladies'],
#  'no': ['body', 'body', 'job.', 'unpredictable', 'kid', 'shame.'],
#  'hair': ['from'],
#  'neck': ['down.'],
#  'down.': ['It’s', 'I', 'I', 'People'],
#  'making': ['love'],
#  'dolphin.': ['Oh,'],
#  'smooth,': ['just'],
#  'slip': ['and'],
#  'slide.': ['Just'],
#  'Just': ['black', 'sneak', 'give', 'give', 'choke', 'try'],
#  'black': ['fish,', 'friends.'],
#  'fish,': ['Tilikum,'],
#  'Tilikum,': ['all'],
#  'bed': ['every'],
#  'every': ['night,',
#   'day.”',
#   'single',
#   'day.',
#   'day.',
#   'day…',
#   'day',
#   'single'],
#  'night,': ['you', 'everybody.'],
#  'know?': ['Ooh-wee.',
#   'Maybe',
#   'I',
#   'Especially',
#   'Like,',
#   'I',
#   'I',
#   'And,',
#   'Your',
#   'And'],
#  'Ooh-wee.': ['You'],
#  'mess': ['with'],
#  'Jewish': ['dude', 'male'],
#  'afterwards.': ['It’s', 'I'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for,'],
#  'exfoliated': ['today.”'],
#  'today.”': ['“This'],
#  '“This': ['is'],
#  'J-date,': ['more'],
#  'loofah': ['date.'],
#  'date.': ['Thanks'],
#  'Thanks': ['for'],
#  'rug': ['burn,'],
#  'burn,': ['Avi.”'],
#  'Avi.”': ['And'],
#  'men,': ['no'],
#  'odor.': ['None.'],
#  'None.': ['They'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility.': ['That’s'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['from.I', 'out.', 'out', 'out,', 'to'],
#  'from.I': ['think'],
#  'unspoken': ['understanding,'],
#  'understanding,': ['uh,'],
#  'between': ['each', 'your'],
#  'each': ['other,', 'other.'],
#  'other,': ['because'],
#  'half-Filipino': ['and'],
#  'half-Japanese': ['and'],
#  'we’re': ['both', 'too', 'expected', 'so', 'such', 'trying', 'hippies,'],
#  'both': ['half-fancy', 'total,', 'are'],
#  'half-fancy': ['Asian…'],
#  'Asian…': ['…and'],
#  'half-jungle': ['Asian.'],
#  'Yeah!': ['You', 'Never'],
#  'difference.': ['The'],
#  'fancy': ['Asians', 'things'],
#  'Asians': ['are', 'host'],
#  'Chinese,': ['the'],
#  'Japanese.': ['They'],
#  'host': ['Olympics.', 'diseases.'],
#  'Olympics.': ['Jungle'],
#  'Jungle': ['Asians'],
#  'diseases.': ['It’s…'],
#  'different.': ['But', 'It’s'],
#  'East': ['Coast,'],
#  'Coast,': ['going'],
#  'going': ['to', 'to', 'back', 'through', 'through', 'to'],
#  'private': ['school,', 'school,', 'school'],
#  'school,': ['playing', 'too.'],
#  'playing': ['lacrosse,', 'chess', 'dumb', 'Candy'],
#  'lacrosse,': ['uh,'],
#  'learning': ['Latin'],
#  'Latin': ['and'],
#  'chess': ['and'],
#  'rugby.': ['He'],
#  'Filipino': ['Carlton,'],
#  'Carlton,': ['OK?'],
#  'didn’t': ['know', 'think', 'know', 'know'],
#  'anything': ['about'],
#  'Vietnamese': ['people'],
#  'dates,': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['of', 'from', 'effect'],
#  'Los': ['Angeles'],
#  'Angeles': ['called'],
#  'called': ['Pho', 'Lean', 'bossy.'],
#  'Pho': ['Show.'],
#  'Show.': ['He'],
#  '“It’s': ['authentic', 'not'],
#  'authentic': ['Vietnamese.'],
#  'Vietnamese.': ['I'],
#  'read': ['about', 'more'],
#  'Yelp!”': ['I'],
#  'authentic,': ['OK?”'],
#  'OK?”': ['You', '‘Cause', 'And', 'And'],
#  'tell,': ['first', 'but'],
#  'name,': ['’cause'],
#  'number': ['in'],
#  'Second': ['of'],
#  'all,': ['you'],
#  'bathroom.': ['If'],
#  'legit,': ['the'],
#  'bathroom': ['would'],
#  'double': ['as', 'standard'],
#  'supply': ['closet.'],
#  'closet.': ['When'],
#  'When': ['I',
#   'you',
#   'I',
#   'I’ve',
#   'can',
#   'can',
#   'in–',
#   'you’re',
#   'somebody',
#   'somebody',
#   'I',
#   'it’s'],
#  'pee,': ['I'],
#  'gallons': ['of'],
#  'bleach,': ['an'],
#  'ATM': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner.': ['And'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'nice.': ['We'],
#  'leave': ['this', 'without', 'you,'],
#  'deaf': ['and'],
#  'emotionally': ['abused.I'],
#  'abused.I': ['grew'],
#  'too.': ['Him', 'We', 'But', 'They'],
#  'Him': ['and'],
#  'total,': ['like,'],
#  'school': ['Asians.'],
#  'Asians.': ['We'],
#  'big': ['hippies,', 'fantasy', 'impact'],
#  'hippies,': ['too.', 'I’d'],
#  'backpack': ['through'],
#  'Southeast': ['Asia.'],
#  'Asia.': ['We'],
#  'yoga.': ['We'],
#  'ayahuasca': ['ceremonies.'],
#  'ceremonies.': ['We'],
#  'silent': ['meditation'],
#  'meditation': ['retreats.'],
#  'retreats.': ['That’s'],
#  'pay': ['$800', 'for'],
#  '$800': ['to'],
#  'shut': ['up', 'up!”', 'the'],
#  'weekend.': ['We'],
#  'gluten-free,': ['which'],
#  'means': ['we', 'I', 'the', 'you’re'],
#  'bread': ['that', 'that’s'],
#  'tastes': ['like', 'when'],
#  'free-range': ['Chewbacca.'],
#  'Chewbacca.': ['We'],
#  'lesbian': ['bread'],
#  'like…': ['…a'],
#  '…a': ['thousand'],
#  'thousand': ['percent'],
#  'daily': ['fiber…', 'basis.', 'basis…'],
#  'fiber…': ['and'],
#  '20': ['percent'],
#  'spoken': ['word'],
#  'word': ['poetry.', '“bossy”', '“bossy,”'],
#  'poetry.': ['When'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom.'],
#  'poem': ['about…'],
#  'about…': ['…supporting'],
#  '…supporting': ['Caitlyn'],
#  'Caitlyn': ['Jenner'],
#  'Jenner': ['or'],
#  'whatever.': ['And'],
#  'so,': ['it’s', 'in', 'motherfucker,'],
#  'funny,': ['right,'],
#  'Asian,': ['too.'],
#  'sometimes,': ['all'],
#  'hippy-dippy': ['shit'],
#  'do…': ['makes'],
#  'doing': ['an', 'anything.', 'jack', 'it.Now'],
#  'impression': ['of'],
#  'Like,': ['we', 'you', '“I', 'I’m', '“You,'],
#  'Chinese': ['scrolls', 'ladies', 'ladies,'],
#  'scrolls': ['up'],
#  'wall…': ['and'],
#  'neither': ['of'],
#  'us': ['know', 'to,'],
#  'mean.': ['We’re'],
#  'We’re': ['like,', 'like,'],
#  'seems': ['to', 'to'],
#  'well': ['with'],
#  'Buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'Pier': ['1'],
#  '1': ['Imports.'],
#  'Imports.': ['That'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point,', 'of'],
#  'good': ['feng', 'in', 'night,'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house.Him': ['and'],
#  'four': ['years', 'days'],
#  'years': ['and', 'old,', 'old,'],
#  'I–': ['I', 'I–', 'I,', 'I,'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose…': ['because…'],
#  'because…': ['I', 'they’re'],
#  'pressuring': ['him'],
#  'wacky': ['women’s'],
#  'intuition.': ['That’s'],
#  'proposals': ['really'],
#  'work,': ['OK?', 'we', 'and'],
#  'woman': ['has', 'is', 'wants', 'who'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'man’s': ['head.', 'eye'],
#  'head.': ['First'],
#  'First': ['passively'],
#  'passively': ['and'],
#  'doesn’t': ['get', 'see', 'have', 'have', 'believe'],
#  'message,': ['extremely'],
#  'extremely': ['aggressively.', 'itchy.'],
#  'aggressively.': ['You'],
#  'threaten': ['to'],
#  'without': ['ever'],
#  'actually': ['leaving,'],
#  'leaving,': ['because'],
#  'old': ['and', 'as', 'Chinese'],
#  'late': ['to'],
#  'there': ['and', 'and', 'is', 'for', 'for', 'would'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again.': ['So,', 'And', 'It’s', 'But'],
#  '“I’m': ['just', 'gonna', 'just'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere.'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  '“Shut': ['the'],
#  'up!': ['Fine,'],
#  'Fine,': ['will'],
#  'marry': ['me?”', 'him'],
#  'me?”': ['And'],
#  'afterwards,': ['the', 'and'],
#  'always,': ['like,'],
#  'God!': ['He', 'It’s', 'And'],
#  'proposed!”': ['“It'],
#  '“It': ['came'],
#  'nowhere.': ['And', 'And'],
#  'look,': ['he'],
#  'exact': ['ring'],
#  'ring': ['I'],
#  'wanted.': ['How'],
#  'Maybe': ['he', 'because'],
#  'Pinterest': ['page', 'page…'],
#  'page': ['or'],
#  'something…': ['that'],
#  'sent': ['to'],
#  'best': ['friend,', 'you', 'articles'],
#  'friend,': ['that'],
#  'send': ['to'],
#  'day.”': ['Let'],
#  'Let': ['me', 'me'],
#  'page…': ['he’s'],
#  'Pinterested': ['in'],
#  'engaged': ['on'],
#  'Saturday.': ['I'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['Tuesday…'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'C.e.o.s, they don’t know that seems to take its toll on J-date, more options now.”.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
# Comedian 1: Lewis
lewis_text = data.transcript.loc['lewis']
lewis_text[:500]
lewis_dict = markov_chain(lewis_text)

print("LEWIS:",generate_sentence(lewis_dict))

# Comedian 2: Hasan
hasan_text = data.transcript.loc['hasan']
hasan_text[:500]
hasan_dict = markov_chain(hasan_text)

print("HASAN:",generate_sentence(hasan_dict))

# Comedian 3: Kathleen
kathleen_text = data.transcript.loc['kathleen']
kathleen_text[:500]
kathleen_dict = markov_chain(kathleen_text)

print("KATHLEEN:",generate_sentence(kathleen_dict))
# Out:
# LEWIS: Companionship. And goddammit I mean, for risking your desk.” [audience laughs] All of books. I’ve.
# HASAN: Anything is a bunch of him, and finding out of Cards just so stressful, I’ve.
# KATHLEEN: Neighborhood. And the… but she still definitely there. I would turn the only are afraid,.

# %%
def generate_sentence1(chain):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Generate a Random sentence length
    count = random.randint(15, 25)

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a random punctuation
    punc = random.choice(list("!?."))
    sentence += punc
    return(sentence)

def generate_sentence2(chain):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Generate a Random sentence length
    count = random.randint(15, 25)

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
        if i>5 and sentence[-1] in "!?.":
            return(sentence)

    # End it with a random punctuation
    punc = random.choice(list("!?."))
    sentence += punc
    return(sentence)

# %%
# Comedian 1: Lewis
print("LEWIS:",generate_sentence1(lewis_dict))
print("LEWIS:",generate_sentence2(lewis_dict))


# Comedian 2: Hasan
print("HASAN:",generate_sentence1(hasan_dict))
print("HASAN:",generate_sentence2(hasan_dict))

# Comedian 3: Kathleen
print("KATHLEEN:",generate_sentence1(kathleen_dict))
print("KATHLEEN:",generate_sentence2(kathleen_dict))
# Out:
# LEWIS: Fuck, then finally a bitch, they’re nuts, OK? I sat down there was spinning at the first?
# LEWIS: Launching their pills, and I could have come out and we tripled down the whole thing they overpaid.
# HASAN: Thank Jeff Mason and tell Melania? “Listen, babe, last year in this moment — I want to be a joke. Now,.
# HASAN: Someone is president, it feels like …I have to be alternative fact.
# KATHLEEN: 7:40 AM. I knew that has to have bought a different unemployed than if you guys. I will!
# KATHLEEN: Bang, bang. No wine. That’s it. I got 37 bucks.
